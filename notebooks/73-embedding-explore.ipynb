# %% [markdown]
# # imports

# %%
from gensim.models import Word2Vec

# %% [markdown]
# # constants

# %%
W2V_MODEL = "../data/word2vec.model" # NOT STORED IN REPOSITORY; GENERATED BY NOTEBOOK

# %% [markdown]
# # explore

# %%
w2v_model = Word2Vec.load(W2V_MODEL)
print(f"Number of words in vocabulary: {len(w2v_model.wv)}")
# Out:
# Number of words in vocabulary: 22292

# %%
print(w2v_model.wv.most_similar('clean', topn=10))
# Out:
# [('tidi', 0.7341182231903076), ('spaciou', 0.7151318788528442), ('immacul', 0.7128661870956421), ('dingi', 0.7013615369796753), ('furnish', 0.6922579407691956), ('remodel', 0.6835771203041077), ('spotless', 0.6819506883621216), ('steril', 0.6768563985824585), ('luxuri', 0.6701444983482361), ('carpet', 0.6663637161254883)]

# %%
print(w2v_model.wv.similarity('clean', 'tidi'))
# Out:
# 0.7341183

# %%
print(w2v_model.wv["clean"])
# Out:
# [-2.16256991e-01 -2.80673476e-03 -2.07015872e-01 -2.40427107e-01
#  -7.72519317e-03  2.42183506e-02 -1.85215428e-01 -3.03419419e-02
#   1.96003333e-01 -1.14154875e-01  1.08687170e-01  3.11406292e-02
#  -1.19572818e-01  1.30427885e-04 -2.44118110e-03 -5.35474271e-02
#  -2.58796513e-01 -5.31309610e-03  8.99348855e-02 -5.14869750e-01
#   4.05276150e-01 -3.72760519e-02  2.51425942e-03 -1.25366688e-01
#   2.16984794e-01 -1.98916495e-02  3.03394645e-01 -1.15569681e-01
#  -3.75475943e-01  8.49337950e-02  1.85592204e-01 -1.10170931e-01
#  -2.14786366e-01 -8.46179649e-02  7.65739679e-02 -1.50621504e-01
#   5.60450666e-02  2.13413075e-01 -2.49606192e-01 -2.53547519e-01
#  -1.46316305e-01  5.66108264e-02 -5.09006903e-02  2.97603190e-01
#   7.21403658e-02  2.68031415e-02 -1.36425406e-01 -8.02974701e-02
#  -6.50044382e-02 -1.31171405e-01  7.05039725e-02 -1.37997335e-02
#   7.62335509e-02  1.46288406e-02  6.82220757e-02  2.13579938e-01
# ...
